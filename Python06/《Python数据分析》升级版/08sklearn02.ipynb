# %%
'''
中心归一化：统计学里面的一个公式


一般情况下
model.score()得到的分数越高，说明模型预测 的准确性就越高

交叉验证 每一份 都会进行学习

如果要确定多个超参数 则需要GridSearchCV

特征归一化

中心归一化，或者是 最大 最小归一化
在训练的时候 对 每一列 进行归一化；归一化以后会产生一个参数scale，不同的参数集会产生不同的scale；
拿到scale后 对测试集 进行归一化，
在训练集上进行归一化的得到scale，用这个参数 再去在测试集上归一化，
相当于从训练集上归一化出一个模型，然后拿着这个归一化后的模型去处理测试集上的样本
###########
特征和标签是不同的，是预测房价

测试模型的调用
训练后的模型
model.predict(X_test)#返回测试样本的预测标签，比如会预测出新一轮房价的大小
model.score(X_test, y_test) #根据预测值 和 真实值 计算评分

#####
特征降维--主成分分析（PCA）
用于减少数据集的维度，同时保持数据集中的 对方差贡献最大的特征
保留低阶主成分，忽略高阶成分，这样的低阶成分往往能够保留住数据的最重要方面

维度太高的时候 对特征进行一次降维

特征选取和特征降维不太一样

特征选取：假如有10个特征，选取其中的3个代表性比较好的特征；
特征降维：是对特征进行了一个转换，假如有10个特征，进行降维之后也生成3个特征，
        但是转换之后的三个特征和原来里面的10个特征并不一样，将10维的特征映射到
        三维特征的里面（相当于转换了坐标系）
    降维是可以保持数据集中对方差贡献最大的特征 

降维可能会提升模型的准确度，也可能会降低模型的承载能力
PCA可以降维，特征选择也可以降维，但是PCA降维后的特征不是原来的特征，
而是经过坐标系转换而来的特征

怎么算出特征向量：
方差和协方差：用于衡量一系列点在它们的中心或均值附近的分散程度
方差：衡量这些点在一个维度上的偏差
协方差：衡量一个维度是否会对另一个维度有所影响，从而查看两个维度之间的关系；

某个维度和自身之间的协方差就是其方差；

协方差代表两个向量之间的关联程度；

**************************
协方差矩阵
如果数据是D维的（x1,x2,....xd） 则可以计算出（x1,x2）,(x1,x3),....,(x1,xd),(x2,x3),....(x2,xd)...(xd-1,xd)
之间的协方差，由于协方差的对称性，再加上各维度自身的协方差，可以构成协方差矩阵

协方差最后是一个值，这些值构成的矩阵就是协方差矩阵

协方差为正，代表两个变量变化趋势相同，反之亦然

PCA：通过线性变化将原数据映射到新的坐标系统中，使映射后的第一个坐标上的方差最大（即第一个主成分），
第二个坐标上的方差第二大（即第二个主成分）.....














'''
